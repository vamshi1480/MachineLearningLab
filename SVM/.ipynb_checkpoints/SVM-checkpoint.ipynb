# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Week8_Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.shape
# Out:
# (150, 6)

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
print(np.array(df.columns))
# Out:
# ['Id' 'SepalLengthCm' 'SepalWidthCm' 'PetalLengthCm' 'PetalWidthCm'
#  'Species']

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
print(df["Species"].unique())
# Out:
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %%
df.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
df.drop('Id', axis=1, inplace=True)

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
sns.histplot(df["SepalLengthCm"], bins=20, color="orange",kde=True)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
sns.histplot(df["SepalWidthCm"], bins=20, color="green",kde=True)
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='Count'>

# %%
sns.histplot(df["PetalLengthCm"], bins=20, color="red",kde=True)
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Count'>

# %%
plt.scatter(df["SepalLengthCm"], df["SepalWidthCm"], color="green") 
plt.xlabel("SepalLength")
plt.ylabel("SepalWidth")
# Out:
# Text(0, 0.5, 'SepalWidth')

# %%
sns.set(style="whitegrid")
sns.scatterplot(x=df["SepalLengthCm"], y=df["SepalWidthCm"], color="green")
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
sns.set(style="whitegrid")
sns.scatterplot(df, color="green")
# Out:
# <Axes: >

# %%
g = sns.FacetGrid(df, hue="Species")
g.map_dataframe(sns.scatterplot, x='SepalLengthCm', y='SepalWidthCm')
g.add_legend()
plt.show()

# %%
species = df["Species"].unique()
list(species)
# Out:
# ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %%
sns.boxplot(x=df["Species"], y=df["PetalWidthCm"])
# Out:
# <Axes: xlabel='Species', ylabel='PetalWidthCm'>

# %%
species = df['Species'].unique()
data = [df[df['Species'] == sp]['PetalWidthCm'] for sp in species]

# Create boxplot
plt.boxplot(data, labels=species)

# Titles and labels
plt.title("Petal Width by Species")
plt.xlabel("Species")
plt.ylabel("Petal Width (cm)")
plt.grid(True)

plt.show()

# %%
data
# Out:
# [0     0.2
#  1     0.2
#  2     0.2
#  3     0.2
#  4     0.2
#  5     0.4
#  6     0.3
#  7     0.2
#  8     0.2
#  9     0.1
#  10    0.2
#  11    0.2
#  12    0.1
#  13    0.1
#  14    0.2
#  15    0.4
#  16    0.4
#  17    0.3
#  18    0.3
#  19    0.3
#  20    0.2
#  21    0.4
#  22    0.2
#  23    0.5
#  24    0.2
#  25    0.2
#  26    0.4
#  27    0.2
#  28    0.2
#  29    0.2
#  30    0.2
#  31    0.4
#  32    0.1
#  33    0.2
#  34    0.1
#  35    0.2
#  36    0.2
#  37    0.1
#  38    0.2
#  39    0.2
#  40    0.3
#  41    0.3
#  42    0.2
#  43    0.6
#  44    0.4
#  45    0.3
#  46    0.2
#  47    0.2
#  48    0.2
#  49    0.2
#  Name: PetalWidthCm, dtype: float64,
#  50    1.4
#  51    1.5
#  52    1.5
#  53    1.3
#  54    1.5
#  55    1.3
#  56    1.6
#  57    1.0
#  58    1.3
#  59    1.4
#  60    1.0
#  61    1.5
#  62    1.0
#  63    1.4
#  64    1.3
#  65    1.4
#  66    1.5
#  67    1.0
#  68    1.5
#  69    1.1
#  70    1.8
#  71    1.3
#  72    1.5
# ...

# %%
sns.boxplot(x=df["Species"], y=df["PetalLengthCm"])
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>
